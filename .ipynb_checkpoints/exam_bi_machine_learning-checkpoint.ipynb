# %% [markdown]
# # Machine Learning Exam - Football Matches
#
# # Stage 1: Problem Foundation
# ## Hypothesis
#
# ### Regn (Samlet data pr. Kamp)
# * Der scores flere mål i regnvejrskampe end tørvejrskampe
# * Der bliver uddelt flere kort i regnvejrskampe vs tørvejr
# * Bliver der generelt lavet flere “fouls” i en regnvejrskamp?
# * Der bliver dømt flere straffespark i regnvejr end tørvejskampe
#
# ### Afleveringer og hjemmebanefordel (Individuel data pr. kamp)
# * Højere afleveringsprocenter fører til flere mål end gennemsnittet
# * Kampe er vundet med højere boldbesiddelse
# * Kampe er vundet med flest skud på mål
# * Man vinder oftere med hjemmebanefordel
# * Hjemmebanehold får mindre “fouls” stemt imod sig end udebanehold
#
# ### Straffespark / Hjørnespark / Frispark (Individuel data pr. kamp)
# * Mængden af kort et hold modtager har en korrelation til at man taber kampen
# * Mængden af kort et hold modtager har en korrelation til at man vinder kampen
# * Mængden af hjørnespark har en korrelation til at vinde kampe
# * Man vinder flere kampe, jo flere frispark et hold får dømt til deres fordel

# %% [markdown]
# # Stage 2: Data Preparation And Exploration
# ## Data Collection
# ### Import data
# Her importerer vi vores raw data vi har fået. Dataen er fodbold-kamp data fra perioden 2025-02-04 -3026-03-13

# %%
import pandas as pd
rawdf = pd.read_csv("data/matchdataraw.csv")
cleaneddf = rawdf.copy()
cleaneddf.head()
# Out:
#    COMPETITION_WYID  MATCH_WYID  TEAM_WYID  SHOTS  FOULS  CORNERS  REDCARDS  \
# 0               335     1699867       7458     11      9        4         0
# 1               335     1699867       7499     12      8        4         0
# 2               335     1699868       7456      5     14        2         0
# 3               335     1699868       7455     12     16        4         0
# 4               335     1699869       7460     14     10        4         0
#
#    YELLOWCARDS  OFFSIDES  DRIBBLES  GOALS  XGPERSHOT  AVGDISTANCE      XG  \
# 0            1         2        65      0      0.077         20.7  0.8455
# 1            0         0        28      2      0.083         22.6  0.9959
# 2            1         2        19      0      0.069         14.1  0.3439
# 3            1         1        32      2      0.077         22.2  0.9293
# 4            1         0        38      3      0.097         20.9  1.3590
#
#    PROGRESSIVERUNS  TOUCHESINBOX  FOULSSUFFERED  SHOTSONTARGET  SHOTSBLOCKED  \
# 0               11            13              8              1             2
# 1                5            11              9              7             2
# 2                7             7             16              1             0
# 3                9            13             14              3             1
# 4               11            16              8              8             3
#
#    SHOTSOUTSIDEBOX  SHOTSOUTSIDEBOXONTARGET  SHOTSONPOST  SHOTSWIDE  \
# 0                7                        1            0          8
# 1                8                        4            0          3
# 2                0                        0            0          4
# 3                7                        2            0          8
# 4                6                        2            0          3
#
#    SHOTSFROMBOX  SHOTSFROMBOXONTARGET  FREEKICKS  SHOTSFROMDANGERZONE  \
# 0             4                     0          0                    4
# 1             4                     3          2                    4
# 2             5                     1         10                    3
# 3             5                     1          7                    4
# 4             8                     6          0                    4
#
#    TOTALTHROWINS  LEFTTHROWINS  RIGHTTHROWINS  MATCH_WYID.1  \
# 0             23             8             15       1699867
# 1             17            10              7       1699867
# 2             31            13             18       1699868
# 3             21             9             12       1699868
# 4             18            10              8       1699869
#
#                           MATCHLABEL                     DATE  \
# 0  Nordsjælland - SønderjyskE, 0 - 2  2015-07-17 17:00:00.000
# 1  Nordsjælland - SønderjyskE, 0 - 2  2015-07-17 17:00:00.000
# 2        Midtjylland - Viborg, 2 - 0  2015-07-18 15:00:00.000
# 3        Midtjylland - Viborg, 2 - 0  2015-07-18 15:00:00.000
# 4                  OB - Hobro, 3 - 0  2015-07-19 12:30:00.000
#
#                    DATEUTC MATCHSTATUS  COMPETITION_WYID.1  SEASON_WYID  \
# 0  2015-07-17 15:00:00.000      Played                 335         9493
# 1  2015-07-17 15:00:00.000      Played                 335         9493
# 2  2015-07-18 13:00:00.000      Played                 335         9493
# 3  2015-07-18 13:00:00.000      Played                 335         9493
# 4  2015-07-19 10:30:00.000      Played                 335         9493
#
#    ROUND_WYID  GAMEWEEK
# 0     4165479         1
# 1     4165479         1
# 2     4165479         1
# 3     4165479         1
# 4     4165479         1

# %% [markdown]
# ## Cleaning
# ### Håndtering af NaN

# %%
cleaneddf.isnull().sum
cleaneddf.isna().sum()
# Out:
# COMPETITION_WYID           0
# MATCH_WYID                 0
# TEAM_WYID                  0
# SHOTS                      0
# FOULS                      0
# CORNERS                    0
# REDCARDS                   0
# YELLOWCARDS                0
# OFFSIDES                   0
# DRIBBLES                   0
# GOALS                      0
# XGPERSHOT                  0
# AVGDISTANCE                0
# XG                         0
# PROGRESSIVERUNS            0
# TOUCHESINBOX               0
# FOULSSUFFERED              0
# SHOTSONTARGET              0
# SHOTSBLOCKED               0
# SHOTSOUTSIDEBOX            0
# SHOTSOUTSIDEBOXONTARGET    0
# SHOTSONPOST                0
# SHOTSWIDE                  0
# SHOTSFROMBOX               0
# SHOTSFROMBOXONTARGET       0
# FREEKICKS                  0
# SHOTSFROMDANGERZONE        0
# TOTALTHROWINS              0
# LEFTTHROWINS               0
# RIGHTTHROWINS              0
# MATCH_WYID.1               0
# MATCHLABEL                 0
# DATE                       0
# DATEUTC                    0
# MATCHSTATUS                0
# COMPETITION_WYID.1         0
# SEASON_WYID                0
# ROUND_WYID                 0
# GAMEWEEK                   0
# dtype: int64

# %% [markdown]
# ### Håndtering af duplikeret rækker

# %%
cleaneddf.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Håndtering af inkonsistente værdier (Danmark,DK)
#   Vi fjerner "Expected goals per shot (XGPERSHOT)" pga. den er inkonsistent og der mangler data / forklaring på hvordan den laves korrekt

# %%
cleaneddf.drop(columns=["XGPERSHOT"], inplace=True)
print("XGPERSHOT i kolonner?", "XGPERSHOT" in cleaneddf.columns)
# Out:
# XGPERSHOT i kolonner? False

# %% [markdown]
# ### Håndtering af outliers

# %% [markdown]
# Vi finder vores ekstreme outliers

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in C:\Users\jonas\anaconda3\envs\streamlitenv\Lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\jonas\anaconda3\envs\streamlitenv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\jonas\anaconda3\envs\streamlitenv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\jonas\anaconda3\envs\streamlitenv\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\jonas\anaconda3\envs\streamlitenv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\jonas\anaconda3\envs\streamlitenv\Lib\site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\jonas\anaconda3\envs\streamlitenv\Lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in C:\Users\jonas\anaconda3\envs\streamlitenv\Lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\jonas\anaconda3\envs\streamlitenv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\jonas\anaconda3\envs\streamlitenv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\jonas\anaconda3\envs\streamlitenv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

performance_cols = [
    'SHOTS', 'FOULS', 'CORNERS', 'YELLOWCARDS', 'OFFSIDES', 
    'DRIBBLES', 'GOALS', 'PROGRESSIVERUNS', 'TOUCHESINBOX', 
    'FOULSSUFFERED', 'SHOTSONTARGET', 'FREEKICKS'
]

plt.figure(figsize=(15, 8))
cleaneddf[performance_cols].boxplot()

plt.xticks(rotation=45)
plt.title('Boxplot over vigtige performance parametre')
plt.ylabel('Antal pr. kamp')
plt.tight_layout()
plt.show()

# %%
# Vi finder hvilken outlier der er ekstrem i dribbles kategorien
outliers = cleaneddf[cleaneddf['DRIBBLES'] > 62]
display(outliers.head())

# Vi definerer en liste med alle de kamp-ID'er, vi vil ha fjernet
matches_to_remove = [1699867, 1699952, 2497370, 2720158, 2818322, 1699964]

# Vi sikrer at kolonnen er integer 
cleaneddf['MATCH_WYID'] = cleaneddf['MATCH_WYID'].astype(int)

# Vi fjerner listen
cleaneddf = cleaneddf[~cleaneddf['MATCH_WYID'].isin(matches_to_remove)]

# Vi dobbelt tjekker om de er blevet fjernet
outliers_check = cleaneddf[cleaneddf['DRIBBLES'] > 62]
display(outliers_check.head())
# Out:
#       COMPETITION_WYID  MATCH_WYID  TEAM_WYID  SHOTS  FOULS  CORNERS  \
# 0                  335     1699867       7458     11      9        4
# 162                335     1699952       7457     10      9        6
# 182                335     1699964       7456     11     17        6
# 183                335     1699964       7457     10      7        3
# 1107               335     2497370       7461     16      7        8
#
#       REDCARDS  YELLOWCARDS  OFFSIDES  DRIBBLES  GOALS  AVGDISTANCE      XG  \
# 0            0            1         2        65      0         20.7  0.8455
# 162          0            1         1        67      1         23.5  0.3297
# 182          0            1         3        65      1         21.5  0.9750
# 183          0            1         2        84      0         24.3  0.3538
# 1107         0            0         2        65      1         15.5  2.3040
#
#       PROGRESSIVERUNS  TOUCHESINBOX  FOULSSUFFERED  SHOTSONTARGET  \
# 0                  11            13              8              1
# 162                 6             8             12              2
# 182                 8            12              5              4
# 183                17             9              8              2
# 1107               11            22             15              4
#
#       SHOTSBLOCKED  SHOTSOUTSIDEBOX  SHOTSOUTSIDEBOXONTARGET  SHOTSONPOST  \
# 0                2                7                        1            0
# 162              4                9                        2            0
# 182              4                7                        2            0
# 183              4                7                        2            0
# 1107             7                4                        0            0
#
#       SHOTSWIDE  SHOTSFROMBOX  SHOTSFROMBOXONTARGET  FREEKICKS  \
# 0             8             4                     0          0
# 162           4             1                     0          3
# 182           3             4                     2          3
# 183           4             3                     0          6
# 1107          5            12                     4          5
#
#       SHOTSFROMDANGERZONE  TOTALTHROWINS  LEFTTHROWINS  RIGHTTHROWINS  \
# 0                       4             23             8             15
# 162                     1             23             9             14
# 182                     4             32            21             11
# 183                     1             24            10             14
# 1107                    7             36            10             26
#
#       MATCH_WYID.1                         MATCHLABEL  \
# 0          1699867  Nordsjælland - SønderjyskE, 0 - 2
# 162        1699952               Randers - AGF, 4 - 1
# 182        1699964                Viborg - AGF, 1 - 0
# 183        1699964                Viborg - AGF, 1 - 0
# 1107       2497370         Silkeborg - Brøndby, 1 - 3
#
#                          DATE                  DATEUTC MATCHSTATUS  \
# 0     2015-07-17 17:00:00.000  2015-07-17 15:00:00.000      Played
# 162   2015-11-06 19:30:00.000  2015-11-06 18:30:00.000      Played
# 182   2015-11-27 17:00:00.000  2015-11-27 16:00:00.000      Played
# 183   2015-11-27 17:00:00.000  2015-11-27 16:00:00.000      Played
# 1107  2017-11-26 18:00:00.000  2017-11-26 17:00:00.000      Played
#
#       COMPETITION_WYID.1  SEASON_WYID  ROUND_WYID  GAMEWEEK
# 0                    335         9493     4165479         1
# 162                  335         9493     4165479        15
# 182                  335         9493     4165479        17
# 183                  335         9493     4165479        17
# 1107                 335       181370     4405217        17
# Empty DataFrame
# Columns: [COMPETITION_WYID, MATCH_WYID, TEAM_WYID, SHOTS, FOULS, CORNERS, REDCARDS, YELLOWCARDS, OFFSIDES, DRIBBLES, GOALS, AVGDISTANCE, XG, PROGRESSIVERUNS, TOUCHESINBOX, FOULSSUFFERED, SHOTSONTARGET, SHOTSBLOCKED, SHOTSOUTSIDEBOX, SHOTSOUTSIDEBOXONTARGET, SHOTSONPOST, SHOTSWIDE, SHOTSFROMBOX, SHOTSFROMBOXONTARGET, FREEKICKS, SHOTSFROMDANGERZONE, TOTALTHROWINS, LEFTTHROWINS, RIGHTTHROWINS, MATCH_WYID.1, MATCHLABEL, DATE, DATEUTC, MATCHSTATUS, COMPETITION_WYID.1, SEASON_WYID, ROUND_WYID, GAMEWEEK]
# Index: []

# %%
import matplotlib.pyplot as plt

performance_cols = [
    'SHOTS', 'FOULS', 'CORNERS', 'YELLOWCARDS', 'OFFSIDES', 
    'DRIBBLES', 'GOALS', 'PROGRESSIVERUNS', 'TOUCHESINBOX', 
    'FOULSSUFFERED', 'SHOTSONTARGET', 'FREEKICKS'
]

plt.figure(figsize=(15, 8))
cleaneddf[performance_cols].boxplot()

plt.xticks(rotation=45)
plt.title('Boxplot over vigtige performance parametre')
plt.ylabel('Antal pr. kamp')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Structering
# ### Vejr data

# %% [markdown]
# ## Transformation
# ### Kategoriske værdier til numeriske

# %%
cleaneddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4528 entries, 2 to 4539
# Data columns (total 38 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   COMPETITION_WYID         4528 non-null   int64
#  1   MATCH_WYID               4528 non-null   int64
#  2   TEAM_WYID                4528 non-null   int64
#  3   SHOTS                    4528 non-null   int64
#  4   FOULS                    4528 non-null   int64
#  5   CORNERS                  4528 non-null   int64
#  6   REDCARDS                 4528 non-null   int64
#  7   YELLOWCARDS              4528 non-null   int64
#  8   OFFSIDES                 4528 non-null   int64
#  9   DRIBBLES                 4528 non-null   int64
#  10  GOALS                    4528 non-null   int64
#  11  AVGDISTANCE              4528 non-null   float64
#  12  XG                       4528 non-null   float64
#  13  PROGRESSIVERUNS          4528 non-null   int64
#  14  TOUCHESINBOX             4528 non-null   int64
#  15  FOULSSUFFERED            4528 non-null   int64
#  16  SHOTSONTARGET            4528 non-null   int64
#  17  SHOTSBLOCKED             4528 non-null   int64
#  18  SHOTSOUTSIDEBOX          4528 non-null   int64
#  19  SHOTSOUTSIDEBOXONTARGET  4528 non-null   int64
#  20  SHOTSONPOST              4528 non-null   int64
#  21  SHOTSWIDE                4528 non-null   int64
#  22  SHOTSFROMBOX             4528 non-null   int64
#  23  SHOTSFROMBOXONTARGET     4528 non-null   int64
#  24  FREEKICKS                4528 non-null   int64
#  25  SHOTSFROMDANGERZONE      4528 non-null   int64
#  26  TOTALTHROWINS            4528 non-null   int64
#  27  LEFTTHROWINS             4528 non-null   int64
#  28  RIGHTTHROWINS            4528 non-null   int64
#  29  MATCH_WYID.1             4528 non-null   int64
#  30  MATCHLABEL               4528 non-null   object
#  31  DATE                     4528 non-null   object
#  32  DATEUTC                  4528 non-null   object
#  33  MATCHSTATUS              4528 non-null   object
#  34  COMPETITION_WYID.1       4528 non-null   int64
#  35  SEASON_WYID              4528 non-null   int64
#  36  ROUND_WYID               4528 non-null   int64
#  37  GAMEWEEK                 4528 non-null   int64
# dtypes: float64(2), int64(32), object(4)
# memory usage: 1.3+ MB

# %% [markdown]
# #### Vi vil gerne lave DATE og DATEUTC om til et datetime objekt

# %%
# Konverter DATE og DATEUTC til datetime-objekter
cleaneddf['DATE'] = pd.to_datetime(cleaneddf['DATE'])
cleaneddf['DATEUTC'] = pd.to_datetime(cleaneddf['DATEUTC'])

cleaneddf['weekday'] = cleaneddf['DATE'].dt.day_name() 

print(cleaneddf[['DATE', 'weekday']].head())
cleaneddf.info()
# Out:
#                  DATE   weekday
# 2 2015-07-18 15:00:00  Saturday
# 3 2015-07-18 15:00:00  Saturday
# 4 2015-07-19 12:30:00    Sunday
# 5 2015-07-19 12:30:00    Sunday
# 6 2015-07-19 17:00:00    Sunday
# <class 'pandas.core.frame.DataFrame'>
# Index: 4528 entries, 2 to 4539
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   COMPETITION_WYID         4528 non-null   int64
#  1   MATCH_WYID               4528 non-null   int64
#  2   TEAM_WYID                4528 non-null   int64
#  3   SHOTS                    4528 non-null   int64
#  4   FOULS                    4528 non-null   int64
#  5   CORNERS                  4528 non-null   int64
#  6   REDCARDS                 4528 non-null   int64
#  7   YELLOWCARDS              4528 non-null   int64
#  8   OFFSIDES                 4528 non-null   int64
#  9   DRIBBLES                 4528 non-null   int64
#  10  GOALS                    4528 non-null   int64
#  11  AVGDISTANCE              4528 non-null   float64
#  12  XG                       4528 non-null   float64
#  13  PROGRESSIVERUNS          4528 non-null   int64
#  14  TOUCHESINBOX             4528 non-null   int64
#  15  FOULSSUFFERED            4528 non-null   int64
#  16  SHOTSONTARGET            4528 non-null   int64
#  17  SHOTSBLOCKED             4528 non-null   int64
#  18  SHOTSOUTSIDEBOX          4528 non-null   int64
#  19  SHOTSOUTSIDEBOXONTARGET  4528 non-null   int64
#  20  SHOTSONPOST              4528 non-null   int64
#  21  SHOTSWIDE                4528 non-null   int64
#  22  SHOTSFROMBOX             4528 non-null   int64
#  23  SHOTSFROMBOXONTARGET     4528 non-null   int64
#  24  FREEKICKS                4528 non-null   int64
#  25  SHOTSFROMDANGERZONE      4528 non-null   int64
#  26  TOTALTHROWINS            4528 non-null   int64
#  27  LEFTTHROWINS             4528 non-null   int64
#  28  RIGHTTHROWINS            4528 non-null   int64
#  29  MATCH_WYID.1             4528 non-null   int64
#  30  MATCHLABEL               4528 non-null   object
#  31  DATE                     4528 non-null   datetime64[ns]
#  32  DATEUTC                  4528 non-null   datetime64[ns]
#  33  MATCHSTATUS              4528 non-null   object
#  34  COMPETITION_WYID.1       4528 non-null   int64
#  35  SEASON_WYID              4528 non-null   int64
#  36  ROUND_WYID               4528 non-null   int64
#  37  GAMEWEEK                 4528 non-null   int64
#  38  weekday                  4528 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(32), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Categorization
#
# ### Kategori med holdnavn og Kategori med nedbør ud fra vejrdata (nedbør mm)

# %%
cleaneddf.head()
# Out:
#    COMPETITION_WYID  MATCH_WYID  TEAM_WYID  SHOTS  FOULS  CORNERS  REDCARDS  \
# 2               335     1699868       7456      5     14        2         0
# 3               335     1699868       7455     12     16        4         0
# 4               335     1699869       7460     14     10        4         0
# 5               335     1699869       7510     14     10        2         0
# 6               335     1699871       7453     11     20        8         0
#
#    YELLOWCARDS  OFFSIDES  DRIBBLES  GOALS  AVGDISTANCE      XG  \
# 2            1         2        19      0         14.1  0.3439
# 3            1         1        32      2         22.2  0.9293
# 4            1         0        38      3         20.9  1.3590
# 5            2         2        29      0         22.3  1.2890
# 6            1         4        15      1         19.6  0.9837
#
#    PROGRESSIVERUNS  TOUCHESINBOX  FOULSSUFFERED  SHOTSONTARGET  SHOTSBLOCKED  \
# 2                7             7             16              1             0
# 3                9            13             14              3             1
# 4               11            16              8              8             3
# 5                3            12              9              9             2
# 6                2            19             10              2             5
#
#    SHOTSOUTSIDEBOX  SHOTSOUTSIDEBOXONTARGET  SHOTSONPOST  SHOTSWIDE  \
# 2                0                        0            0          4
# 3                7                        2            0          8
# 4                6                        2            0          3
# 5                8                        6            1          2
# 6                4                        2            0          4
#
#    SHOTSFROMBOX  SHOTSFROMBOXONTARGET  FREEKICKS  SHOTSFROMDANGERZONE  \
# 2             5                     1         10                    3
# 3             5                     1          7                    4
# 4             8                     6          0                    4
# 5             6                     3          1                    3
# 6             7                     0          4                    4
#
#    TOTALTHROWINS  LEFTTHROWINS  RIGHTTHROWINS  MATCH_WYID.1  \
# 2             31            13             18       1699868
# 3             21             9             12       1699868
# 4             18            10              8       1699869
# 5             27            14             13       1699869
# 6             24            13             11       1699871
#
#                     MATCHLABEL                DATE             DATEUTC  \
# 2  Midtjylland - Viborg, 2 - 0 2015-07-18 15:00:00 2015-07-18 13:00:00
# 3  Midtjylland - Viborg, 2 - 0 2015-07-18 15:00:00 2015-07-18 13:00:00
# 4            OB - Hobro, 3 - 0 2015-07-19 12:30:00 2015-07-19 10:30:00
# 5            OB - Hobro, 3 - 0 2015-07-19 12:30:00 2015-07-19 10:30:00
# 6         AGF - Brøndby, 2 - 1 2015-07-19 17:00:00 2015-07-19 15:00:00
#
#   MATCHSTATUS  COMPETITION_WYID.1  SEASON_WYID  ROUND_WYID  GAMEWEEK   weekday
# 2      Played                 335         9493     4165479         1  Saturday
# 3      Played                 335         9493     4165479         1  Saturday
# 4      Played                 335         9493     4165479         1    Sunday
# 5      Played                 335         9493     4165479         1    Sunday
# 6      Played                 335         9493     4165479         1    Sunday

# %%
import pandas as pd
import numpy as np

team_mapping = {
    7458: 'Nordsjælland', 7499: 'SønderjyskE', 7456: 'Viborg', 
    7455: 'Midtjylland', 7460: 'OB', 7510: 'Hobro', 
    7452: 'København', 7462: 'Randers', 7453: 'Brøndby', 
    7457: 'AGF', 7454: 'AaB', 7451: 'Esbjerg', 
    7484: 'Lyngby', 7461: 'Silkeborg', 7465: 'Horsens', 
    7566: 'FC Helsingør', 7488: 'Vendsyssel', 7473: 'Vejle', 
    7490: 'Hvidovre', 7469: 'Fredericia'
}

cleaneddf['TEAM_WYID'] = pd.to_numeric(cleaneddf['TEAM_WYID'], errors='coerce').fillna(0).astype(int)

cleaneddf['Hold'] = cleaneddf['TEAM_WYID'].map(team_mapping)

cleaneddf['Total Cards'] = pd.to_numeric(cleaneddf['REDCARDS'], errors='coerce').fillna(0) + \
                           pd.to_numeric(cleaneddf['YELLOWCARDS'], errors='coerce').fillna(0)

cleaneddf['Total Rain'] = np.nan
cleaneddf['Kategori med nedbør'] = 'Vejrdata mangler'

if 'MATCHLABEL' in cleaneddf.columns:
    matchlabel_data = cleaneddf.pop('MATCHLABEL')
    cleaneddf['MATCHLABEL'] = matchlabel_data

pd.set_option('display.max_columns', None)
cleaneddf.head()
# Out:
#    COMPETITION_WYID  MATCH_WYID  TEAM_WYID  SHOTS  FOULS  CORNERS  REDCARDS  \
# 2               335     1699868       7456      5     14        2         0
# 3               335     1699868       7455     12     16        4         0
# 4               335     1699869       7460     14     10        4         0
# 5               335     1699869       7510     14     10        2         0
# 6               335     1699871       7453     11     20        8         0
#
#    YELLOWCARDS  OFFSIDES  DRIBBLES  GOALS  AVGDISTANCE      XG  \
# 2            1         2        19      0         14.1  0.3439
# 3            1         1        32      2         22.2  0.9293
# 4            1         0        38      3         20.9  1.3590
# 5            2         2        29      0         22.3  1.2890
# 6            1         4        15      1         19.6  0.9837
#
#    PROGRESSIVERUNS  TOUCHESINBOX  FOULSSUFFERED  SHOTSONTARGET  SHOTSBLOCKED  \
# 2                7             7             16              1             0
# 3                9            13             14              3             1
# 4               11            16              8              8             3
# 5                3            12              9              9             2
# 6                2            19             10              2             5
#
#    SHOTSOUTSIDEBOX  SHOTSOUTSIDEBOXONTARGET  SHOTSONPOST  SHOTSWIDE  \
# 2                0                        0            0          4
# 3                7                        2            0          8
# 4                6                        2            0          3
# 5                8                        6            1          2
# 6                4                        2            0          4
#
#    SHOTSFROMBOX  SHOTSFROMBOXONTARGET  FREEKICKS  SHOTSFROMDANGERZONE  \
# 2             5                     1         10                    3
# 3             5                     1          7                    4
# 4             8                     6          0                    4
# 5             6                     3          1                    3
# 6             7                     0          4                    4
#
#    TOTALTHROWINS  LEFTTHROWINS  RIGHTTHROWINS  MATCH_WYID.1  \
# 2             31            13             18       1699868
# 3             21             9             12       1699868
# 4             18            10              8       1699869
# 5             27            14             13       1699869
# 6             24            13             11       1699871
#
#                  DATE             DATEUTC MATCHSTATUS  COMPETITION_WYID.1  \
# 2 2015-07-18 15:00:00 2015-07-18 13:00:00      Played                 335
# 3 2015-07-18 15:00:00 2015-07-18 13:00:00      Played                 335
# 4 2015-07-19 12:30:00 2015-07-19 10:30:00      Played                 335
# 5 2015-07-19 12:30:00 2015-07-19 10:30:00      Played                 335
# 6 2015-07-19 17:00:00 2015-07-19 15:00:00      Played                 335
#
#    SEASON_WYID  ROUND_WYID  GAMEWEEK   weekday         Hold  Total Cards  \
# 2         9493     4165479         1  Saturday       Viborg            1
# 3         9493     4165479         1  Saturday  Midtjylland            1
# 4         9493     4165479         1    Sunday           OB            1
# 5         9493     4165479         1    Sunday        Hobro            2
# 6         9493     4165479         1    Sunday      Brøndby            1
#
#    Total Rain Kategori med nedbør                   MATCHLABEL
# 2         NaN    Vejrdata mangler  Midtjylland - Viborg, 2 - 0
# 3         NaN    Vejrdata mangler  Midtjylland - Viborg, 2 - 0
# 4         NaN    Vejrdata mangler            OB - Hobro, 3 - 0
# 5         NaN    Vejrdata mangler            OB - Hobro, 3 - 0
# 6         NaN    Vejrdata mangler         AGF - Brøndby, 2 - 1

# %% [markdown]
# ## Total info
# - Total Cards
# - Total Shots
# - Total Fouls
# - Total Corners
# - Total Red cards
# - Total Yellow cards
# - Total Off-side
# - Total Dribbles
# - Total Goals
# - Total Progressive runs
# - Total Free kicks
# - Total Throw ins
# - Total Rain (hvis vejrdata bliver implemeneteret)
#
# Her samler vi kampene til en kamp. Så to rows bliver til en row der beskriver hele kampen

# %%
import pandas as pd
import numpy as np

cols_to_sum = {
    'SHOTS': 'Total Shots',
    'FOULS': 'Total Fouls',
    'CORNERS': 'Total Corners',
    'REDCARDS': 'Total Red cards',
    'YELLOWCARDS': 'Total Yellow cards',
    'OFFSIDES': 'Total Off-side',
    'DRIBBLES': 'Total Dribbles',
    'GOALS': 'Total Goals',
    'PROGRESSIVERUNS': 'Total Progressive runs',
    'FREEKICKS': 'Total Free kicks',
    'TOTALTHROWINS': 'Total Throw ins'
}


match_df = cleaneddf.groupby(['MATCH_WYID', 'MATCHLABEL']).agg({
    **{col: 'sum' for col in cols_to_sum.keys()}
}).reset_index()

match_df.rename(columns=cols_to_sum, inplace=True)

match_df['Total Cards'] = match_df['Total Red cards'] + match_df['Total Yellow cards']

# 5. 
match_df['Total Rain'] = np.nan
match_df['Kategori med nedbør'] = 'Vejrdata mangler'

pd.set_option('display.max_columns', None)
match_df.head()
# Out:
#    MATCH_WYID                   MATCHLABEL  Total Shots  Total Fouls  \
# 0     1699868  Midtjylland - Viborg, 2 - 0           17           30
# 1     1699869            OB - Hobro, 3 - 0           28           20
# 2     1699870   København - Randers, 3 - 0           20           29
# 3     1699871         AGF - Brøndby, 2 - 1           21           30
# 4     1699872         AaB - Esbjerg, 1 - 1           36           25
#
#    Total Corners  Total Red cards  Total Yellow cards  Total Off-side  \
# 0              6                0                   2               3
# 1              6                0                   3               2
# 2              6                0                   3               2
# 3             11                0                   3               6
# 4             15                0                   4               2
#
#    Total Dribbles  Total Goals  Total Progressive runs  Total Free kicks  \
# 0              51            2                      16                17
# 1              67            3                      14                 1
# 2              73            3                      12                 3
# 3              30            3                       4                 6
# 4              52            2                      13                 1
#
#    Total Throw ins  Total Cards  Total Rain Kategori med nedbør
# 0               52            2         NaN    Vejrdata mangler
# 1               45            3         NaN    Vejrdata mangler
# 2               51            3         NaN    Vejrdata mangler
# 3               38            3         NaN    Vejrdata mangler
# 4               44            4         NaN    Vejrdata mangler

# %% [markdown]
# ### Rettelse af enkelte grammatik-fejl

# %%
cleaneddf = cleaneddf.replace("SønderjyskE", "Sønderjyske")
match_df = match_df.replace("SønderjyskE", "Sønderjyske")

# Check om ændringen er gået igennem
print((cleaneddf == "SønderjyskE").any().any())
print((match_df == "SønderjyskE").any().any())
# Out:
# False
# False

# %% [markdown]
# ### Rettelse af MATCHLABEL til HOMETEAM, AWAYTEAM, HOMEGOAL, AWAYGOAL

# %%
# Split hold og score: 
match_df[['Teams', 'Score']] = match_df['MATCHLABEL'].str.rsplit(', ', n=1, expand=True)

# %%
# Split hjemmhold og udehold:
match_df[['Home Team', 'Away Team']] = match_df['Teams'].str.split(' - ', expand=True)

# %%
# Split scoreline i hjemmemål og udemål
match_df[['Home Goals', 'Away Goals']] = match_df['Score'].str.split('-', expand=True)

# %%
# Check om ændringen er gået igennem
match_df[['Teams', 'Score','Home Team','Away Team','Home Goals','Away Goals']].head()
# Out:
#                   Teams  Score    Home Team Away Team Home Goals Away Goals
# 0  Midtjylland - Viborg  2 - 0  Midtjylland    Viborg         2           0
# 1            OB - Hobro  3 - 0           OB     Hobro         3           0
# 2   København - Randers  3 - 0    København   Randers         3           0
# 3         AGF - Brøndby  2 - 1          AGF   Brøndby         2           1
# 4         AaB - Esbjerg  1 - 1          AaB   Esbjerg         1           1

# %%
# Reorder df:
cols = [
    'MATCH_WYID','MATCHLABEL','Teams','Score','Home Team','Away Team','Home Goals','Away Goals',
    'Total Shots','Total Fouls','Total Corners','Total Red cards','Total Yellow cards',
    'Total Off-side','Total Dribbles','Total Goals','Total Progressive runs',
    'Total Free kicks','Total Throw ins','Total Cards','Total Rain','Kategori med nedbør'
]

match_df = match_df[cols]

# %%
match_df.head()
# Out:
#    MATCH_WYID                   MATCHLABEL                 Teams  Score  \
# 0     1699868  Midtjylland - Viborg, 2 - 0  Midtjylland - Viborg  2 - 0
# 1     1699869            OB - Hobro, 3 - 0            OB - Hobro  3 - 0
# 2     1699870   København - Randers, 3 - 0   København - Randers  3 - 0
# 3     1699871         AGF - Brøndby, 2 - 1         AGF - Brøndby  2 - 1
# 4     1699872         AaB - Esbjerg, 1 - 1         AaB - Esbjerg  1 - 1
#
#      Home Team Away Team Home Goals Away Goals  Total Shots  Total Fouls  \
# 0  Midtjylland    Viborg         2           0           17           30
# 1           OB     Hobro         3           0           28           20
# 2    København   Randers         3           0           20           29
# 3          AGF   Brøndby         2           1           21           30
# 4          AaB   Esbjerg         1           1           36           25
#
#    Total Corners  Total Red cards  Total Yellow cards  Total Off-side  \
# 0              6                0                   2               3
# 1              6                0                   3               2
# 2              6                0                   3               2
# 3             11                0                   3               6
# 4             15                0                   4               2
#
#    Total Dribbles  Total Goals  Total Progressive runs  Total Free kicks  \
# 0              51            2                      16                17
# 1              67            3                      14                 1
# 2              73            3                      12                 3
# 3              30            3                       4                 6
# 4              52            2                      13                 1
#
#    Total Throw ins  Total Cards  Total Rain Kategori med nedbør
# 0               52            2         NaN    Vejrdata mangler
# 1               45            3         NaN    Vejrdata mangler
# 2               51            3         NaN    Vejrdata mangler
# 3               38            3         NaN    Vejrdata mangler
# 4               44            4         NaN    Vejrdata mangler

# %% [markdown]
# ## Validation
# Data er valideret og cleaned. Ingen missing values eller nonsens værdier
#
# ### Vi har to dataframes
#
# #### cleaneddf
# Her opstår der kampe hvor der er to rækker for hver ene kamp. Hver række er fra hvert hold der spillede i den ene kamp. Der er tilføjet en kolonne helt ude til højre, som fortæller hvilket hold rækken tilhøre
#
# #### match_df
# Her er de to rækker merged sammen i en, hvor hele rækken viser total value for hele kampen

# %% [markdown]
# # Stage 3: Data Modeling
